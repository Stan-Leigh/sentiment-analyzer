# %%
import json
import requests
import base64
from PIL import Image
import io
from requests.exceptions import HTTPError

# %% [markdown]
# ### EDEN AI

# %%
headers = {"Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiZDEwNWRiZmMtMjI4Ny00MmE0LWExNWYtZjcxM2UzNzkyZWIxIiwidHlwZSI6ImFwaV90b2tlbiJ9.oLlMnxJrvvjZiZ4exYupUaWNL1ttP7kfRm6muALq0Zo"}

url = "https://api.edenai.run/v2/image/generation"
payload = {
    "providers": "openai",
    "text": "a white siamese cat",
    "resolution": "512x512",
    "fallback_providers": ""
}

response = requests.post(url, json=payload, headers=headers)
result = json.loads(response.text)
print(result['openai']['items'][0]['image_resource_url'])
# Out:
# https://d14uq1pz7dzsdq.cloudfront.net/b51e4ffa-bf0b-424f-b604-53b64ed3642c_.png?Expires=1703446742&Signature=ptDd-iM5wgIcsNNVLb42kYDED~m9VugXLEZ2D-uM3sc9LW-ZM28KZ1MoxiecSsnR~vKkqW6DQIcemTk~GDbOLNIyhKC5eR1-8QGqksfoYjj8oeGhU2Gmh5x-OAfjtPz7qbcO6QL3oWmDMXdIDbv6HqTgm2AgWFR~MlVN27~SCo~eZY7Dw0mLPcwIt7ZMoOA-Z6AfZW7y-bS6gAf6Axk5-0oI~6v2DIwpMY4bpcJyLTsL11W2U7QtsVqg0JnCYUEH38ISmrLgOON9w2hTsIUwDHGgsWBU1Qvw9EeHcbt5bSihRY4gQGrWty0pqB1R0pcE4CZ5pAji92vEP4vceAs69g__&Key-Pair-Id=K1F55BTI9AHGIK

# %% [markdown]
# ### ABSTRACT AI

# %%
response = requests.get("https://avatars.abstractapi.com/v1/?api_key=ea5ccbd7411848da883799cb564f7858&name=Stanley Florentz")
image_byte = response.content

# Convert the bytes to a readable image using PIL
image = Image.open(io.BytesIO(image_byte))

# Display the image
image.show()

# %% [markdown]
# Very rubbish. It's basically a simple Avatar of the first letter of your first name and the first letter of your last name.

# %%
# URL for the API
url = "https://images.abstractapi.com/v1/url/?"

# Request headers
headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
}

# Request data
data = {
    "api_key": "871fa18aeb7749a8b9ecd072c07f2d8d",
    "lossy": True,
    "url": "https://s3.amazonaws.com/static.abstractapi.com/test-images/dog.jpg",
}

try:
    # Make the POST request
    response = requests.post(url, headers=headers, json=data)
    response.raise_for_status()  # Raise an HTTPError for bad responses

    # If the response status code indicates success, attempt to parse JSON
    if response.status_code == 200:
        json_data = response.json()
        print(json_data)
    else:
        print(f"Error: {response.status_code}")
except HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"An error occurred: {err}")
# Out:
# HTTP error occurred: 500 Server Error: Internal Server Error for url: https://images.abstractapi.com/v1/url/

# %% [markdown]
# ### GETIMG AI

# %%
# URL for the API
url = "https://api.getimg.ai/v1/stable-diffusion/text-to-image"

# Access token (replace with your actual access token)
access_token = "key-2oXhrk7aNUJkaXX802OeLESxni62xJcf9S5fx9PnOsPb28fXkaZ1C0oFVNCxbQZuulUGyE9Ma4ytZNnFn58Dzvab6dI7tqPa"

# Request headers
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json",
}

# Request data
data = {
    "prompt": "Bitcoin and Ethereum",
}

# Make the POST request
response = requests.post(url, headers=headers, json=data)

# Response
getimg_data = response.json()

# %%
getimg_data
# Out:
# {'image': '...',
#  'seed': 344702901,
#  'cost': 0.00294912}

# %%
image_string = (getimg_data['image'])

# Convert the string to bytes
image_bytes = base64.b64decode(image_string)

# Open the image using PIL
image = Image.open(io.BytesIO(image_bytes))

# Display the image
image.show()
